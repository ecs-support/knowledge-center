# %%
Permission_Goods_1

msft = pd.read_csv("data/msft.csv", 
                   dtype = { 'Volume' : np.float64})
msft.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-bd725000fe7c> in <module>
# ----> 1 Permission_Goods_1
#       2
#       3 msft = pd.read_csv("data/msft.csv",
#       4                    dtype = { 'Volume' : np.float64})
#       5 msft.dtypes
#
# NameError: name 'Permission_Goods_1' is not defined

# %%
import pandas as pd

df = pd.read_excel('data/Permission_old.xlsx', 'Sheet1', )
                  
df
# Out:
#                    หน่วยงาน  Tariff Classification(12 N)  \
# 0      กรมการอุตสาหกรรมทหาร                     28011000
# 1      กรมการอุตสาหกรรมทหาร                     28013000
# 2      กรมการอุตสาหกรรมทหาร                     28047000
# 3      กรมการอุตสาหกรรมทหาร                     28062000
# 4      กรมการอุตสาหกรรมทหาร                     28111100
# 5      กรมการอุตสาหกรรมทหาร                     28111990
# 6      กรมการอุตสาหกรรมทหาร                     28112920
# 7      กรมการอุตสาหกรรมทหาร                     28112990
# 8      กรมการอุตสาหกรรมทหาร                     28121100
# 9      กรมการอุตสาหกรรมทหาร                     28121200
# 10     กรมการอุตสาหกรรมทหาร                     28121900
# 11     กรมการอุตสาหกรรมทหาร                     28121900
# 12     กรมการอุตสาหกรรมทหาร                     28129000
# 13     กรมการอุตสาหกรรมทหาร                     28129000
# 14     กรมการอุตสาหกรรมทหาร                     28139000
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
